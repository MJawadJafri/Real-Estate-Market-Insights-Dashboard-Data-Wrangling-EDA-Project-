# %% [markdown]
# <a href="https://colab.research.google.com/github/MJawadJafri/Real-Estate-Market-Insights-Dashboard-Data-Wrangling-EDA-Project-/blob/main/%20Data%20Wrangling%20%26%20EDA%20Project!%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('property_data.csv',sep=',')

# %%
data.head()
# Out:
#    index                                                url   type   purpose  \
# 0      0  https://www.zameen.com/Property/dha_defence_dh...  House  For Sale
# 1      1  https://www.zameen.com/Property/g_15_g-15_1_in...  House  For Sale
# 2      2  https://www.zameen.com/Property/islamabad_g-16...  House  For Sale
# 3      3  https://www.zameen.com/Property/b_17_mpchs_-_m...  House  For Sale
# 4      4  https://www.zameen.com/Property/islamabad_isla...   Flat  For Sale
#
#          area bedroom bath       added            price  \
# 0     1 Kanal       7    6  4 days ago    PKR\n19 Crore
# 1  14.2 Marla       6    6  4 days ago     PKR\n6 Crore
# 2     1 Kanal       8    7  4 days ago     PKR\n7 Crore
# 3     8 Marla       4    6  4 days ago  PKR\n2.65 Crore
# 4   2.4 Marla       1    1  4 days ago     PKR\n40 Lakh
#
#                         location location_city
# 0                    DHA Defence     Islamabad
# 1                           G-15     Islamabad
# 2                           G-16     Islamabad
# 3                           B-17     Islamabad
# 4  Islamabad - Murree Expressway     Islamabad

# %%
data.tail()
# Out:
#         index                                                url  type  \
# 116028  62773  https://www.graana.com/property/360-sqft-shop-...  Shop
# 116029  62774  https://www.graana.com/property/450-sqft-shop-...  Shop
# 116030  62775  https://www.graana.com/property/450-sqft-shop-...  Shop
# 116031  62776  https://www.graana.com/property/350-sqft-shop-...  Shop
# 116032  62777  https://www.graana.com/property/450-sqft-shop-...  Shop
#
#          purpose      area bedroom bath               added      price  \
# 116028  For Rent  360 Sqft       0    0  Added 4 months ago  PKR 15000
# 116029  For Rent  450 Sqft       0    0  Added 4 months ago  PKR 15000
# 116030  For Rent  450 Sqft       0    0  Added 4 months ago  PKR 18000
# 116031  For Rent  350 Sqft       0    0  Added 4 months ago  PKR 20000
# 116032  For Rent  450 Sqft       0    0  Added 4 months ago  PKR 20000
#
#                             location location_city
# 116028                 Sukkur Bypass        Sukkur
# 116029             Rasheed Residency        Sukkur
# 116030                 Sukkur Bypass        Sukkur
# 116031               New Sukkur City        Sukkur
# 116032  Soarth Memon Housing Society        Sukkur

# %%
# prompt: remove null values

data.isnull().sum()
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# index            0
# url              0
# type             0
# purpose          0
# area             0
# bedroom          0
# bath             0
# added            0
# price            0
# location         0
# location_city    0
# dtype: int64

# %%
data
# Out:
#         index                                                url   type  \
# 0           0  https://www.zameen.com/Property/dha_defence_dh...  House
# 1           1  https://www.zameen.com/Property/g_15_g-15_1_in...  House
# 2           2  https://www.zameen.com/Property/islamabad_g-16...  House
# 3           3  https://www.zameen.com/Property/b_17_mpchs_-_m...  House
# 4           4  https://www.zameen.com/Property/islamabad_isla...   Flat
# ...       ...                                                ...    ...
# 116028  62773  https://www.graana.com/property/360-sqft-shop-...   Shop
# 116029  62774  https://www.graana.com/property/450-sqft-shop-...   Shop
# 116030  62775  https://www.graana.com/property/450-sqft-shop-...   Shop
# 116031  62776  https://www.graana.com/property/350-sqft-shop-...   Shop
# 116032  62777  https://www.graana.com/property/450-sqft-shop-...   Shop
#
#          purpose        area bedroom bath               added  \
# 0       For Sale     1 Kanal       7    6          4 days ago
# 1       For Sale  14.2 Marla       6    6          4 days ago
# 2       For Sale     1 Kanal       8    7          4 days ago
# 3       For Sale     8 Marla       4    6          4 days ago
# 4       For Sale   2.4 Marla       1    1          4 days ago
# ...          ...         ...     ...  ...                 ...
# 116028  For Rent    360 Sqft       0    0  Added 4 months ago
# 116029  For Rent    450 Sqft       0    0  Added 4 months ago
# 116030  For Rent    450 Sqft       0    0  Added 4 months ago
# 116031  For Rent    350 Sqft       0    0  Added 4 months ago
# 116032  For Rent    450 Sqft       0    0  Added 4 months ago
#
#                   price                       location location_city
# 0         PKR\n19 Crore                    DHA Defence     Islamabad
# 1          PKR\n6 Crore                           G-15     Islamabad
# 2          PKR\n7 Crore                           G-16     Islamabad
# 3       PKR\n2.65 Crore                           B-17     Islamabad
# 4          PKR\n40 Lakh  Islamabad - Murree Expressway     Islamabad
# ...                 ...                            ...           ...
# 116028        PKR 15000                  Sukkur Bypass        Sukkur
# 116029        PKR 15000              Rasheed Residency        Sukkur
# 116030        PKR 18000                  Sukkur Bypass        Sukkur
# 116031        PKR 20000                New Sukkur City        Sukkur
# 116032        PKR 20000   Soarth Memon Housing Society        Sukkur
#
# [116008 rows x 11 columns]

# %%
data['price']
# Out:
# 0           PKR\n19 Crore
# 1            PKR\n6 Crore
# 2            PKR\n7 Crore
# 3         PKR\n2.65 Crore
# 4            PKR\n40 Lakh
#                ...
# 116028          PKR 15000
# 116029          PKR 15000
# 116030          PKR 18000
# 116031          PKR 20000
# 116032          PKR 20000
# Name: price, Length: 116008, dtype: object

# %%
# prompt: PKR 15000 remove PKR

data['price'] = data['price'].str.replace('PKR', '')
print(data['price'])
# Out:
# 0           \n19 Crore
# 1            \n6 Crore
# 2            \n7 Crore
# 3         \n2.65 Crore
# 4            \n40 Lakh
#               ...
# 116028           15000
# 116029           15000
# 116030           18000
# 116031           20000
# 116032           20000
# Name: price, Length: 116008, dtype: object

# %%
data.head()
# Out:
#    index                                                url   type   purpose  \
# 0      0  https://www.zameen.com/Property/dha_defence_dh...  House  For Sale
# 1      1  https://www.zameen.com/Property/g_15_g-15_1_in...  House  For Sale
# 2      2  https://www.zameen.com/Property/islamabad_g-16...  House  For Sale
# 3      3  https://www.zameen.com/Property/b_17_mpchs_-_m...  House  For Sale
# 4      4  https://www.zameen.com/Property/islamabad_isla...   Flat  For Sale
#
#          area bedroom bath       added         price  \
# 0     1 Kanal       7    6  4 days ago    \n19 Crore
# 1  14.2 Marla       6    6  4 days ago     \n6 Crore
# 2     1 Kanal       8    7  4 days ago     \n7 Crore
# 3     8 Marla       4    6  4 days ago  \n2.65 Crore
# 4   2.4 Marla       1    1  4 days ago     \n40 Lakh
#
#                         location location_city
# 0                    DHA Defence     Islamabad
# 1                           G-15     Islamabad
# 2                           G-16     Islamabad
# 3                           B-17     Islamabad
# 4  Islamabad - Murree Expressway     Islamabad

# %%
# prompt: remove \n

data['price'] = data['price'].str.replace('\n', '')
print(data['price'])
data.head()
# Out:
# 0           19 Crore
# 1            6 Crore
# 2            7 Crore
# 3         2.65 Crore
# 4            40 Lakh
#              ...
# 116028         15000
# 116029         15000
# 116030         18000
# 116031         20000
# 116032         20000
# Name: price, Length: 116008, dtype: object
#    index                                                url   type   purpose  \
# 0      0  https://www.zameen.com/Property/dha_defence_dh...  House  For Sale
# 1      1  https://www.zameen.com/Property/g_15_g-15_1_in...  House  For Sale
# 2      2  https://www.zameen.com/Property/islamabad_g-16...  House  For Sale
# 3      3  https://www.zameen.com/Property/b_17_mpchs_-_m...  House  For Sale
# 4      4  https://www.zameen.com/Property/islamabad_isla...   Flat  For Sale
#
#          area bedroom bath       added       price  \
# 0     1 Kanal       7    6  4 days ago    19 Crore
# 1  14.2 Marla       6    6  4 days ago     6 Crore
# 2     1 Kanal       8    7  4 days ago     7 Crore
# 3     8 Marla       4    6  4 days ago  2.65 Crore
# 4   2.4 Marla       1    1  4 days ago     40 Lakh
#
#                         location location_city
# 0                    DHA Defence     Islamabad
# 1                           G-15     Islamabad
# 2                           G-16     Islamabad
# 3                           B-17     Islamabad
# 4  Islamabad - Murree Expressway     Islamabad

# %%
data.columns
# Out:
# Index(['index', 'url', 'type', 'purpose', 'area', 'bedroom', 'bath', 'added',
#        'price', 'location', 'location_city'],
#       dtype='object')

# %%
selected_data=data[['location_city','location','area','type','purpose','price']]

# %%
selected_data
# Out:
#        location_city                       location        area   type  \
# 0          Islamabad                    DHA Defence     1 Kanal  House
# 1          Islamabad                           G-15  14.2 Marla  House
# 2          Islamabad                           G-16     1 Kanal  House
# 3          Islamabad                           B-17     8 Marla  House
# 4          Islamabad  Islamabad - Murree Expressway   2.4 Marla   Flat
# ...              ...                            ...         ...    ...
# 116028        Sukkur                  Sukkur Bypass    360 Sqft   Shop
# 116029        Sukkur              Rasheed Residency    450 Sqft   Shop
# 116030        Sukkur                  Sukkur Bypass    450 Sqft   Shop
# 116031        Sukkur                New Sukkur City    350 Sqft   Shop
# 116032        Sukkur   Soarth Memon Housing Society    450 Sqft   Shop
#
#          purpose       price
# 0       For Sale    19 Crore
# 1       For Sale     6 Crore
# 2       For Sale     7 Crore
# 3       For Sale  2.65 Crore
# 4       For Sale     40 Lakh
# ...          ...         ...
# 116028  For Rent       15000
# 116029  For Rent       15000
# 116030  For Rent       18000
# 116031  For Rent       20000
# 116032  For Rent       20000
#
# [116008 rows x 6 columns]

# %%
selected_data['location_city'].rename('city')
# Out:
# 0          Islamabad
# 1          Islamabad
# 2          Islamabad
# 3          Islamabad
# 4          Islamabad
#              ...
# 116028        Sukkur
# 116029        Sukkur
# 116030        Sukkur
# 116031        Sukkur
# 116032        Sukkur
# Name: city, Length: 116008, dtype: object

# %%
selected_data
# Out:
#        location_city                       location        area   type  \
# 0          Islamabad                    DHA Defence     1 Kanal  House
# 1          Islamabad                           G-15  14.2 Marla  House
# 2          Islamabad                           G-16     1 Kanal  House
# 3          Islamabad                           B-17     8 Marla  House
# 4          Islamabad  Islamabad - Murree Expressway   2.4 Marla   Flat
# ...              ...                            ...         ...    ...
# 116028        Sukkur                  Sukkur Bypass    360 Sqft   Shop
# 116029        Sukkur              Rasheed Residency    450 Sqft   Shop
# 116030        Sukkur                  Sukkur Bypass    450 Sqft   Shop
# 116031        Sukkur                New Sukkur City    350 Sqft   Shop
# 116032        Sukkur   Soarth Memon Housing Society    450 Sqft   Shop
#
#          purpose       price
# 0       For Sale    19 Crore
# 1       For Sale     6 Crore
# 2       For Sale     7 Crore
# 3       For Sale  2.65 Crore
# 4       For Sale     40 Lakh
# ...          ...         ...
# 116028  For Rent       15000
# 116029  For Rent       15000
# 116030  For Rent       18000
# 116031  For Rent       20000
# 116032  For Rent       20000
#
# [116008 rows x 6 columns]

# %%
selected_data=selected_data['purpose'].str.replace('For','')
# Out:
# 0          Sale
# 1          Sale
# 2          Sale
# 3          Sale
# 4          Sale
#           ...
# 116028     Rent
# 116029     Rent
# 116030     Rent
# 116031     Rent
# 116032     Rent
# Name: purpose, Length: 116008, dtype: object

# %%
selected_data
# Out:
#        location_city                       location        area   type  \
# 0          Islamabad                    DHA Defence     1 Kanal  House
# 1          Islamabad                           G-15  14.2 Marla  House
# 2          Islamabad                           G-16     1 Kanal  House
# 3          Islamabad                           B-17     8 Marla  House
# 4          Islamabad  Islamabad - Murree Expressway   2.4 Marla   Flat
# ...              ...                            ...         ...    ...
# 116028        Sukkur                  Sukkur Bypass    360 Sqft   Shop
# 116029        Sukkur              Rasheed Residency    450 Sqft   Shop
# 116030        Sukkur                  Sukkur Bypass    450 Sqft   Shop
# 116031        Sukkur                New Sukkur City    350 Sqft   Shop
# 116032        Sukkur   Soarth Memon Housing Society    450 Sqft   Shop
#
#          purpose       price
# 0       For Sale    19 Crore
# 1       For Sale     6 Crore
# 2       For Sale     7 Crore
# 3       For Sale  2.65 Crore
# 4       For Sale     40 Lakh
# ...          ...         ...
# 116028  For Rent       15000
# 116029  For Rent       15000
# 116030  For Rent       18000
# 116031  For Rent       20000
# 116032  For Rent       20000
#
# [116008 rows x 6 columns]
